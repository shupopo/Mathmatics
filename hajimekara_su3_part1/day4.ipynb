# %% [markdown]
# ## p. 52
# (1)
# 焦点(0,2)
# 準線 y = -2

# %% [markdown]
# (2)
# 焦点：(1,1)
# 準線：(-1,0)

# %% [markdown]
# ## p. 58 Practice 16

# %%
# リファレンス
# http://daily-tech.hatenablog.com/entry/2018/04/13/084734

import matplotlib.pyplot as plt
import numpy as np
import math

def generateVecFromEllipse(a, b):
  
  t = np.linspace(0, 2 * math.pi, 101) 
  t = np.reshape(t, (t.shape[0], 1))
  
  xVec = np.zeros((t.shape))
  yVec = np.zeros((t.shape))
  for i in range(t.shape[0]):
    xVec[i] = a * math.cos(t[i])
    yVec[i] = b * math.sin(t[i])
  
  data = np.concatenate((xVec, yVec),  axis=1)
  return data

def plotData(dataOrg):
  
  fig, ax = plt.subplots(ncols = 1, figsize=(10, 10))
  plt.xlim(-10, 10)
  plt.ylim(-10, 10)
  ax.plot(dataOrg[:, 0], dataOrg[:, 1])

# %%
# (1)
dataEl = generateVecFromEllipse(3, 2)

plotData(dataEl)

# %%
# (2)
dataEl = generateVecFromEllipse(math.sqrt(2), 2)

plotData(dataEl)

# %% [markdown]
# ## p. 67 Practice 17

# %%
# (1)
def generateVecFromEllipse(a, b):
  
  t = np.linspace(0, 2 * math.pi, 101) 
  t = np.reshape(t, (t.shape[0], 1))
  
  xVec = np.zeros((t.shape))
  yVec = np.zeros((t.shape))
  for i in range(t.shape[0]):
    xVec[i] = a / math.cos(t[i])
    yVec[i] = b * math.tan(t[i])
  
  data = np.concatenate((xVec, yVec),  axis=1)
  return data

def plotData(dataOrg):
  
  fig, ax = plt.subplots(ncols = 1, figsize=(10, 10))
  plt.xlim(-10, 10)
  plt.ylim(-10, 10)
  ax.plot(dataOrg[:, 0], dataOrg[:, 1])

# %%
# https://benesse.jp/teikitest/kou/math/math3/k00342.html
# ↑双曲線の媒介変数表示の仕方
dataEl = generateVecFromEllipse(1, math.sqrt(3))

plotData(dataEl)

# %%
# (2)

def generateVecFromEllipse(a, b):
  
  t = np.linspace(0, 2 * math.pi, 101) 
  t = np.reshape(t, (t.shape[0], 1))
  
  xVec = np.zeros((t.shape))
  yVec = np.zeros((t.shape))
  for i in range(t.shape[0]):
    xVec[i] = a / math.cos(t[i])+1
    yVec[i] = b * math.tan(t[i])
  
  data = np.concatenate((yVec, xVec),  axis=1)
  return data

def plotData(dataOrg):
  
  fig, ax = plt.subplots(ncols = 1, figsize=(10, 10))
  plt.xlim(-10, 10)
  plt.ylim(-10, 10)
  ax.plot(dataOrg[:, 0], dataOrg[:, 1])

# %%
dataEl = generateVecFromEllipse(2, math.sqrt(5))

plotData(dataEl)

# %%
# 焦点
c = math.sqrt(4+5)
c
# Out:
# 3.0
